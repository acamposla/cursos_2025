# %% [markdown]
# # NumPy Review (Optional)

# %%
import numpy as np

# %%
# seed function Pseudo-random number, not truly number that is predictable.

# %% [markdown]
# ## np.arange()

# %% [markdown]
# np.arange(start= , stop= , step)
#
# - Like a Python list, but with a fixed size and common data type for all elements

# %%
np.arange(5) #1d array
# Out:
# array([0, 1, 2, 3, 4])

# %%
np.arange(start=1, stop=6, step=2) #including lower bound, exclusing upper bound
# Out:
# array([1, 3, 5])

# %% [markdown]
# ## np.random.randint(low, high, size)

# %% [markdown]
# - Generates numners between a lower bound(inclusive) and upper bound (exlusive)
# - The size parameter dictates the shape of the ndarray

# %%
np.random.randint(low=0, high=10, size=(3, 4))
# Out:
# array([[0, 8, 2, 5],
#        [9, 1, 3, 5],
#        [6, 6, 9, 1]])

# %% [markdown]
# ## np.column_stack((a,b))

# %% [markdown]
# Stacks two one-dimensional ndarrays on top of each other

# %%
a = np.arange(1,4)
b = np.arange(4,7)
b
# Out:
# array([4, 5, 6])

# %%
np.column_stack((a,b))
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %% [markdown]
# ## Transposing and Reshaping

# %%
x = np.arange(6)

# %%
b = x.reshape(3,2)

# %%
b.T
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %% [markdown]
# ## Numpy.diag()

# %% [markdown]
# - Create a diagonal arrangement out of the numbers we suppy

# %%
np.diag([1, 2, 3])
# Out:
# array([[1, 0, 0],
#        [0, 2, 0],
#        [0, 0, 3]])

# %% [markdown]
# # THE OBJECT HIRARCHY

# %%
import matplotlib.pyplot as plt 
import numpy as np
from IPython.display import Image, display

# %%
x = np.arange(1, 5)
y = np.array([1, 4, 9, 16])

# %%
plt.plot(x, y)

# %%
figure = "matplotfig.jpg"

# %%
display(Image(filename=figure))

# %%
anatomy = "anatomy.jpg"
display(Image(anatomy))

# %% [markdown]
# # **stateful** y **stateless**

# %% [markdown]
# ### 1. ¿Qué significa "stateful"?
#
# - **Stateful = "con memoria"**
# - Imagina que tienes una pizarra en la que cada vez que dibujas, el programa recuerda **automáticamente** dónde estás dibujando.
# - **pyplot** es una interfaz stateful:
#   - Cuando llamas a funciones como `plt.plot()`, Matplotlib ya tiene un "lienzo" (la figura y los ejes) **creados y listos** para usarse.
#   - **No necesitas decirle** en qué figura o eje dibujar: Matplotlib lo hace por ti.
# - **Ventaja:** Es rápido y fácil para hacer gráficos simples en una sesión interactiva.
# - **Ejemplo sencillo:**
#   ```python
#   import matplotlib.pyplot as plt
#   import numpy as np
#
#   x = np.arange(0, 1, 0.1)
#   y = np.arange(0, 10, 1)
#   plt.plot(x, y)  # Dibuja la línea en la "pizarra" que Matplotlib ya tiene preparada.
#   plt.title("Gráfico sencillo")
#   plt.show()      # Muestra el gráfico.
#   ```
#
# ---
#
# ### 2. ¿Qué significa "stateless" o "orientado a objetos"?
#
# - **Stateless = "sin memoria oculta"**
# - En este caso, **tú creas y manejas** la pizarra (la figura) y cada parte de ella (los ejes) **manualmente**.
# - Esto se conoce como el **enfoque orientado a objetos**.
# - **Ventaja:**
#   - Te da **total control** sobre cada parte del gráfico.
#   - Es ideal para crear gráficos complejos o con **varios subgráficos** (más de un eje, cada uno con sus propios detalles).
# - **Ejemplo sencillo:**
#   ```python
#   import matplotlib.pyplot as plt
#   import numpy as np
#
#   # Creas explícitamente la figura y los ejes
#   fig, ax = plt.subplots()
#
#   x = np.arange(0, 1, 0.1)
#   y = np.arange(0, 10, 1)
#
#   ax.plot(x, y)         # Dibuja la línea en el eje que tú controlas.
#   ax.set_title("Gráfico con control total")
#
#   plt.show()            # Muestra el gráfico.
#   ```
#
# ---
#
# ### 3. ¿Por qué es importante esta diferencia?
#
# - **Usar solo pyplot (stateful)** es genial para cosas rápidas y simples, pero:
#   - **Se vuelve confuso** cuando necesitas crear **varios gráficos** o modificar partes muy específicas de un gráfico.
# - **Usar el enfoque orientado a objetos (stateless)** te permite:
#   - **Saber exactamente** en qué figura y en qué eje estás trabajando.
#   - **Modificar detalles** (como el color de un solo tick, leyendas, etiquetas, etc.) sin que se mezclen con otros gráficos.
#
# ---
#
# ### Resumen Final
#
# - **Stateful (pyplot):**
#   - **Automático y sencillo.**
#   - El programa "recuerda" la figura y los ejes para ti.
#
# - **Stateless (orientado a objetos):**
#   - **Control total y explícito.**
#   - Tú creas y manejas cada objeto (figura y ejes) manualmente.
#
# En resumen, para gráficos rápidos y simples puedes usar **pyplot** (stateful), pero si tu gráfico se complica o necesitas mucha personalización, es mejor usar el enfoque orientado a objetos (stateless) para tener un control más claro y preciso.

# %% [markdown]
# # Your First Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(444)

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(444)

rng = np.arange(50)
rnd = np.random.randint(0, 10, size=(3, rng.size))
yrs = 1950 + rng


fig, ax = plt.subplots(figsize=(5, 3))

ax.stackplot(yrs, rng+rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
ax.set_title('Combined debt growth over time')
ax.legend(loc='upper left')
ax.set_ylabel('Total debt')
ax.set_xlim(xmin=yrs[0], xmax=yrs[-1])

fig.tight_layout()
plt.show()

# %%
print(rnd)
# Out:
# [[3 0 7 8 3 4 7 6 8 9 2 2 2 0 3 8 0 6 6 0 3 0 6 7 9 3 8 7 3 2 6 9 2 9 8 9
#   3 2 2 8 1 5 6 7 6 0 0 0 0 4]
#  [8 1 9 8 5 8 9 4 6 6 4 1 8 2 7 9 3 4 2 5 0 0 8 1 0 9 9 3 2 7 6 0 5 5 4 8
#   3 4 9 4 7 1 5 4 4 0 2 2 5 8]
#  [5 6 6 1 1 6 8 4 1 0 9 2 3 7 3 3 2 7 8 6 6 7 5 7 3 9 1 3 0 4 7 5 1 5 1 4
#   9 7 2 4 3 7 9 2 2 0 1 5 2 4]]
